# %%
import pandas as pd

# %%
job_details=pd.read_csv('job_details_int - job_details.csv')
job_category=pd.read_csv('job_categories_master_int - job_categories.csv')
skill_set=pd.read_csv('skill_set_int - skill_set.csv')
company=pd.read_csv('company - company.csv')
applicants=pd.read_csv('applicants - applicants.csv')
job_applied=pd.read_csv('job_applied_int - job_applied.csv')
company.head(30)
# Out:
#     id                                     name                     address  \
# 0    1                                  SAMSUNG                   Hinjewadi
# 1    2                           Devops Company         Office No 78, Nigdi
# 2    3                                     NIKE             office 10, Pune
# 3    4  Global International School  Foundation               office10,Pune
# 4    5                                     Test                        test
# 5    6                                      IBM                    Adin 404
# 6    7                                 Infosys                   Hinjewadi
# 7    8                            Test company        office 33, chinnchwad
# 8    9                            Chat Paradise                 2 Chat lane
# 9   10                          Cadence academy               2 Burger lane
# 10  11                           General Motors              chinchwad Pune
# ...

# %%
company['business_type'].value_counts()
# Out:
# Pvt Ltd         8
# IT              3
# Software        2
# Banking         1
# Hvs             1
# Education       1
# Marketing       1
# IT.             1
# IT services     1
# Business        1
# Retail sales    1
# Pvt Ltd         1
# Business        1
# Finance         1
# Pvt ltd         1
# osm             1
# asdf            1
# Hj              1
# asdfsf          1
# School          1
# Restaurant      1
# Name: business_type, dtype: int64

# %%
company['no_of_employee'].value_counts()
# Out:
# 1-10       51
# 50-100     14
# 11-50       6
# 200-500     4
# 100-200     3
# Name: no_of_employee, dtype: int64

# %%
print(company['state_id'].value_counts())
# Out:
# 22      203
# 10      120
# 17      113
# 2        80
# 4271     36
#        ...
# 34        1
# 32        1
# 31        1
# 7         1
# 674       1
# Name: state_id, Length: 74, dtype: int64

# %%
company['source'].value_counts()
# Out:
# jobPiker    433
# handson     292
# appcast     236
# jobpiker      1
# Name: source, dtype: int64

# %%
company['status'].value_counts()
# Out:
# 1    958
# 0      4
# Name: status, dtype: int64

# %%
company['recruitment'].value_counts()
# Out:
# 0    934
# 1     28
# Name: recruitment, dtype: int64

# %%
company['language_id'].value_counts()
# Out:
# 1    906
# 0     56
# Name: language_id, dtype: int64

# %%
company['timezone'].value_counts()
# Out:
# 5.5     614
# -3.5    241
# -8       12
# -9       10
# -6        9
# -5        9
# 10        9
# -12       8
# 9.5       8
# -11       8
# -3        7
# -4        6
# -4.5      5
# -9.5      5
# -7        3
# -10       3
# 0         1
# -         1
# 4.5       1
# -2        1
# +5.5      1
# Name: timezone, dtype: int64

# %%
job_category.head(30)
# Out:
#      id                              category  country_id
# 0   185                            Accounting         101
# 1   186                  Admin / Receptionist         101
# 2   187                           Back Office         101
# 3   188              Salon Beauty and Fitness         101
# 4   189                  Business Development         101
# 5   190                  Chartered Accountant         101
# 6   191        Computer / Data Entry Operator         101
# 7   192                       Content Writing         101
# 8   193                             Cook/Chef         101
# 9   194                            Counsellor         101
# 10  195                       Delivery Driver         101
# 11  196  Digital Marketing / Online Marketing         101
# 12  197              Driver / Delivery Driver         101
# 13  198                          DTP Operator         101
# 14  199                    Engineer / Telecom         101
# ...

# %%
job_category['category'].value_counts()
# Out:
# Government                          3
# Accounting                          3
# Legal                               3
# Automotive                          3
# Sales                               3
#                                    ..
# Translator                          1
# Receptionist / Front Office Desk    1
# Transport and Logistics             1
# Office Boy / Peon                   1
# Back Office                         1
# Name: category, Length: 101, dtype: int64

# %%
job_category['country_id'].value_counts()
# Out:
# 101    61
# 231    53
# 38     52
# Name: country_id, dtype: int64

# %%
skill_set.head(30)
# Out:
#     id  user_id                  category_id  \
# 0    1      588                          187
# 1    3      714                      352,370
# 2    4      724                      370,375
# 3    5      595      219,186,189,389,192,194
# 4    6      683                  365,370,375
# 5    7      731                      365,376
# 6   10      635                  379,376,372
# 7   11      746                          186
# 8   12      749                          217
# 9   18      587          186,187,188,189,192
# 10  20      761                  352,355,367
# 11  21      593                      185,186
# 12  22      754                          427
# 13  24      614                          362
# 14  29      780  188,189,190,389,429,191,200
# 15  31      792                          384
# 16  38      799                      194,196
# 17  39      803                          359
# 18  40      804                          359
# 19  41      806                  200,221,392
# ...

# %%
applicants.head(30)
# Out:
#      id  user_id  dob    age gender  address locality_id  city_id  state_id  \
# 0   214     1200  NaN  21-25      m      NaN   Hindmotor     5511        41
# 1   213     1198  NaN  26-30      m      NaN        Sgga      704         9
# 2   212     1196  NaN  21-25      m      NaN      jhgfcx     4510        37
# 3   211     1194  NaN  26-30      m      NaN       Gagag    91767        10
# 4   210     1189  NaN  21-25      m      NaN         Vvv     3659        35
# 5   209     1188  NaN  21-25      m      NaN         Vvb     1558        17
# 6   208     1187  NaN  21-25      m      NaN         Hgg     4460        36
# 7   207     1186  NaN  21-25      m      NaN         Bvv     4460        36
# 8   206     1184  NaN   0-20      m      NaN         NaN    82415       664
# 9   205     1183  NaN  21-25      m      NaN           d        7         2
# 10  204     1181  NaN  31-40      m      NaN     Lalaept      285         2
# ...

# %%
applicants['gender'].value_counts()
# Out:
# m        153
# f         45
# na         8
# Male       7
# ?????      1
# Name: gender, dtype: int64

# %%
applicants['age'].value_counts()
# Out:
# 21-25    119
# 26-30     66
# 31-40     14
# 41-50      6
# 0-20       6
# 25         2
# 51-60      1
# Name: age, dtype: int64

# %%
applicants['locality_id'].value_counts()
# Out:
# Test         9
# Lalapet      7
# Saidabad     7
# Kk           6
# Pimpri       4
#             ..
# dfghj        1
# Tg           1
# Manikonda    1
# dfg          1
# Vvb          1
# Name: locality_id, Length: 128, dtype: int64

# %%
applicants['state_id'].value_counts()
# Out:
# 2       51
# 22      34
# 4271    17
# 36      16
# 10      16
# 3        8
# 8        7
# 5        6
# 6        5
# 41       5
# 1        4
# 9        4
# 4264     3
# 38       3
# 4275     3
# 17       3
# 4        2
# 7        2
# 11       2
# 4242     2
# 29       2
# 37       1
# 666      1
# 34       1
# 4269     1
# 4268     1
# 35       1
# 675      1
# 671      1
# 668      1
# 665      1
# 39       1
# 664      1
# 4243     1
# 32       1
# 4239     1
# 4235     1
# 4234     1
# 4231     1
# 31       1
# Name: state_id, dtype: int64

# %%
applicants['city_id'].value_counts()
# Out:
# 2763     16
# 4460     14
# 287      13
# 707      12
# 6         9
#          ..
# 605       1
# 2476      1
# 71254     1
# 91724     1
# 82173     1
# Name: city_id, Length: 98, dtype: int64

# %%
applicants['country_id'].value_counts()
# Out:
# 101    176
# 231     32
# 38       6
# Name: country_id, dtype: int64

# %%
applicants['has_experience'].value_counts()
# Out:
# 0    163
# 1     51
# Name: has_experience, dtype: int64

# %%
job_applied.head(30)
# Out:
#      id  job_id  applicant_id       applied_date interview_date  \
# 0   426   54786           850  08/25/21 02:11 pm            NaN
# 1   425   54786           860  08/20/21 10:49 am            NaN
# 2   424   54788           860  08/20/21 10:14 am            NaN
# 3   423   54708           800  08/12/21 11:45 am            NaN
# 4   422   54723          1084  08/12/21 11:43 am            NaN
# 5   421   54681           800  08/12/21 11:39 am            NaN
# 6   420   54722          1084  08/12/21 11:38 am            NaN
# 7   419   54728          1084  08/12/21 11:37 am            NaN
# 8   418   54731          1084  08/12/21 11:37 am            NaN
# 9   417   54729          1084  08/11/21 03:06 pm            NaN
# 10  402   54793          1186  08/09/21 01:59 pm            NaN
# 11  401   54780           844  08/09/21 01:59 pm            NaN
# 12  400   54793          1198  08/09/21 01:20 pm       08/09/21
# 13  399   54690          1198  08/09/21 01:19 pm            NaN
# ...

# %%
job_applied['status'].value_counts()
# Out:
# awaiting_review       282
# interview_schedule     69
# shortlisted            34
# hired                   8
# phone_screened          7
# reviewed                4
# interviewed             3
# rejected                2
# resigned                1
# offer_accepted          1
# offer_issued            1
# Name: status, dtype: int64
